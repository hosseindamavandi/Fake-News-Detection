# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Preprocessing.ipynb
# ## Preprocessed Text Classification Dataset

# %%
# %cd drive/MyDrive/Neuromatch
# Out:
# /content/drive/MyDrive/Neuromatch

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from gensim.models import Word2Vec
import re

# %%
true_data = pd.read_csv('datasets/True.csv')
fake_data = pd.read_csv('datasets/Fake.csv')
true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
# Adding labels
true_data["label"] = np.ones(len(true_data),dtype=int)
fake_data["label"] = np.zeros(len(fake_data),dtype=int)

true_data.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
data = pd.concat((true_data,fake_data),axis=0)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ MB
# None

# %%
data = data.sample(frac=1)
data.head(10)
# Out:
#                                                    title  \
# 16664  Tillerson urges Iraq, Kurds to resolve conflic...
# 2031   Congress will raise debt ceiling, has many opt...
# 9441   Obama confident Pacific trade deal will be app...
# 5672    WATCH: The NRA Just Got Caught Desecrating A ...
# 13072  WOW! MSNBC’s Senior Political Analyst Hammers ...
# 20845  NATO urges trading partners to step up pressur...
# 16307  Czech election winner Babis warms to minority ...
# 14400  Macron says not in French interests for German...
# 10226  MAJOR LIBERAL RAG RELUCTANTLY PUBLISHES Articl...
# 5015    Ballet Dancing Great Who Defected From Soviet...
#
#                                                     text       subject  \
# 16664  BAGHDAD (Reuters) - U.S. Secretary of State Re...     worldnews
# 2031   WASHINGTON (Reuters) - The U.S. Congress will ...  politicsNews
# 9441   HANOI (Reuters) - U.S. President Barack Obama ...  politicsNews
# 5672   The NRA claims to care about our military vete...          News
# 13072  Say what??? When former Clinton cheerleader Ma...      politics
# 20845  BRUSSELS (Reuters) - NATO urged all countries ...     worldnews
# 16307  PRAGUE (Reuters) - The anti-establishment ANO ...     worldnews
# 14400  PARIS (Reuters) - President Emmanuel Macron sa...     worldnews
# 10226  The Atlantic, a publication that wouldn t know...      politics
# 5015   Mikhail Baryshnikov is one of the greatest bal...          News
#
#                      date  label
# 16664   October 23, 2017       1
# 2031     August 24, 2017       1
# 9441        May 23, 2016       1
# 5672        June 29, 2016      0
# 13072         Sep 7, 2016      0
# 20845  September 6, 2017       1
# 16307   October 27, 2017       1
# 14400  November 20, 2017       1
# 10226         Aug 5, 2017      0
# 5015      August 17, 2016      0

# %%
data = data.drop("date",axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 16664 to 19595
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   label    44898 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.7+ MB

# %%
nltk.download('all')

# %%
data.head()
# Out:
#                                                    title  \
# 16664  Tillerson urges Iraq, Kurds to resolve conflic...
# 2031   Congress will raise debt ceiling, has many opt...
# 9441   Obama confident Pacific trade deal will be app...
# 5672    WATCH: The NRA Just Got Caught Desecrating A ...
# 13072  WOW! MSNBC’s Senior Political Analyst Hammers ...
#
#                                                     text       subject  label
# 16664  BAGHDAD (Reuters) - U.S. Secretary of State Re...     worldnews      1
# 2031   WASHINGTON (Reuters) - The U.S. Congress will ...  politicsNews      1
# 9441   HANOI (Reuters) - U.S. President Barack Obama ...  politicsNews      1
# 5672   The NRA claims to care about our military vete...          News      0
# 13072  Say what??? When former Clinton cheerleader Ma...      politics      0

# %%
# Tokenize and preprocess text
lemma = WordNetLemmatizer()
pattern = "[^a-zA-Z]"
def preprocess_text(text):
    text = re.sub(pattern, " ", text)  # Cleaning
    tokens = word_tokenize(text.lower())
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    lemmaized_tokens  = [lemma.lemmatize(word) for word in filtered_tokens]
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]

    return stemmed_tokens

# %%
# Train Word2Vec model
all_tokens = [preprocess_text(text) for text in data['text']] + [preprocess_text(title) for title in data['title']]
model = Word2Vec(all_tokens, vector_size=100, window=5, min_count=1, workers=4)

# %%
# Function to vectorize the text
def vectorize_text(text, model):
    vectors = [model.wv[word] for word in text if word in model.wv]
    if not vectors:
        # If none of the words are in the model's vocabulary, return None
        return None
    # Average the word vectors to get the text representation
    avg_vector = sum(vectors) / len(vectors)
    return avg_vector

# %%
# Vectorize the "text" column
data['text_vector'] = data['text'].apply(lambda x: vectorize_text(preprocess_text(x), model))

# Vectorize the "title" column
data['title_vector'] = data['title'].apply(lambda x: vectorize_text(preprocess_text(x), model))

# Print the new DataFrame
print(data)
# Out:
#                                                    title  \
# 16664  Tillerson urges Iraq, Kurds to resolve conflic...
# 2031   Congress will raise debt ceiling, has many opt...
# 9441   Obama confident Pacific trade deal will be app...
# 5672    WATCH: The NRA Just Got Caught Desecrating A ...
# 13072  WOW! MSNBC’s Senior Political Analyst Hammers ...
# ...                                                  ...
# 20155  JUDGE JEANINE IS FURIOUS! “Hillary Won’t Stop ...
# 14306  AUSTRIAN Schools Are Being Radicalized By Youn...
# 15814  [VIDEO] HILLARY’S VAN BLOWS BY ELDERLY PEOPLE ...
# 8952         U.S. lawmakers deadlock on Zika virus funds
# 19595  MOCK ASSASSINATION OF DONALD TRUMP Sparks Outr...
#
#                                                     text       subject  label  \
# 16664  BAGHDAD (Reuters) - U.S. Secretary of State Re...     worldnews      1
# 2031   WASHINGTON (Reuters) - The U.S. Congress will ...  politicsNews      1
# 9441   HANOI (Reuters) - U.S. President Barack Obama ...  politicsNews      1
# 5672   The NRA claims to care about our military vete...          News      0
# 13072  Say what??? When former Clinton cheerleader Ma...      politics      0
# ...                                                  ...           ...    ...
# 20155  Can you blame her for losing her cool with Cro...     left-news      0
# 14306  This story is a perfect example of how Muslim ...      politics      0
# 15814  Hillary s for all  Everyday Americans just not...      politics      0
# 8952   WASHINGTON (Reuters) - U.S. lawmakers deadlock...  politicsNews      1
# 19595  A San Antonio, Texas school is under fire for ...     left-news      0
#
#                                              text_vector  \
# 16664  [-0.20477283, -0.39923164, -0.76950026, 0.4988...
# 2031   [-0.51624465, -1.0285138, -0.2351227, 0.348979...
# 9441   [0.11906749, -1.1680127, -0.6019835, 0.1415119...
# 5672   [0.25936678, -0.6029397, -0.28085747, 0.071327...
# 13072  [0.14806132, 0.0039087017, 0.011725389, -0.402...
# ...                                                  ...
# 20155  [0.0700252, 0.25808194, -0.40047124, -0.558936...
# 14306  [0.12962078, -0.44168234, -0.7573891, 0.057337...
# 15814  [0.32673895, -0.2794471, -0.20500594, 0.165645...
# 8952   [-0.032998372, -1.105648, -0.20950659, 0.69818...
# 19595  [0.48978937, -0.14666317, -0.2765167, -0.14053...
#
#                                             title_vector
# 16664  [-1.0021008, -0.728119, -0.7792489, 1.0723425,...
# 2031   [-0.78196394, -1.4737996, -0.7698689, 0.193961...
# 9441   [-0.24060069, -0.7965209, -0.34325874, -0.5839...
# 5672   [0.5504718, 0.0356774, -0.30024818, -0.2528649...
# 13072  [-0.36672437, 0.4235775, 0.683549, -0.05561705...
# ...                                                  ...
# 20155  [0.4324674, 0.8871304, 0.014821062, -0.3302095...
# 14306  [1.138646, -0.25151455, -1.0108598, -0.8649431...
# 15814  [0.90303344, -0.3520162, -0.11030671, -0.08952...
# 8952   [-0.21994646, -1.2674323, -0.08792147, 0.81676...
# 19595  [1.2108308, -0.46300662, 0.53410715, -0.576159...
#
# [44898 rows x 6 columns]

# %%
data.head()
# Out:
#                                                    title  \
# 16664  Tillerson urges Iraq, Kurds to resolve conflic...
# 2031   Congress will raise debt ceiling, has many opt...
# 9441   Obama confident Pacific trade deal will be app...
# 5672    WATCH: The NRA Just Got Caught Desecrating A ...
# 13072  WOW! MSNBC’s Senior Political Analyst Hammers ...
#
#                                                     text       subject  label  \
# 16664  BAGHDAD (Reuters) - U.S. Secretary of State Re...     worldnews      1
# 2031   WASHINGTON (Reuters) - The U.S. Congress will ...  politicsNews      1
# 9441   HANOI (Reuters) - U.S. President Barack Obama ...  politicsNews      1
# 5672   The NRA claims to care about our military vete...          News      0
# 13072  Say what??? When former Clinton cheerleader Ma...      politics      0
#
#                                              text_vector  \
# 16664  [-0.20477283, -0.39923164, -0.76950026, 0.4988...
# 2031   [-0.51624465, -1.0285138, -0.2351227, 0.348979...
# 9441   [0.11906749, -1.1680127, -0.6019835, 0.1415119...
# 5672   [0.25936678, -0.6029397, -0.28085747, 0.071327...
# 13072  [0.14806132, 0.0039087017, 0.011725389, -0.402...
#
#                                             title_vector
# 16664  [-1.0021008, -0.728119, -0.7792489, 1.0723425,...
# 2031   [-0.78196394, -1.4737996, -0.7698689, 0.193961...
# 9441   [-0.24060069, -0.7965209, -0.34325874, -0.5839...
# 5672   [0.5504718, 0.0356774, -0.30024818, -0.2528649...
# 13072  [-0.36672437, 0.4235775, 0.683549, -0.05561705...

# %%
# Drop rows with missing vector representations
data = data.dropna()

# %%
# data.to_csv('/content/drive/MyDrive/Neuromatch/ANN/temp/preprocessed_dataset.csv')

# %% [markdown]
# # Split the data into training and testing sets

# %%
# Prepare input and target data
X_text = np.array(data['text_vector'].tolist())
X_title = np.array(data['title_vector'].tolist())
X_combined = np.hstack((X_text, X_title))  # Concatenate both vectors
y = np.array(data['label'])

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Training ANN Model

# %%
import torch
import torch.nn as nn

import matplotlib.pyplot as plt
import seaborn as sns

# %%
class ANN(nn.Module):

    def __init__(self):

        super(ANN, self).__init__()
        # self.linear1 = nn.Linear(5008, 200)
        self.linear1 = nn.Linear(200, 1000)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)  # Add dropout layer

        self.linear2 = nn.Linear(1000, 500)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.5)

        self.linear3 = nn.Linear(500, 100)
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)

        self.linear4 = nn.Linear(100, 20)
        self.relu4 = nn.ReLU()
        self.dropout4 = nn.Dropout(0.5)

        self.linear5 = nn.Linear(20, 2)


    def forward(self,x):

        out = self.linear1(x)
        out = self.relu1(out)
        out = self.dropout1(out)

        out = self.linear2(out)
        out = self.relu2(out)
        out = self.dropout2(out)

        out = self.linear3(out)
        out = self.relu3(out)
        out = self.dropout3(out)

        out = self.linear4(out)
        out = self.relu4(out)
        out = self.dropout4(out)

        out = self.linear5(out)

        return out


ann_model = ANN()
optimizer = torch.optim.Adam(ann_model.parameters(),lr=0.01)
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01 * (0.1 ** (epoch // 10)))
# optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)


error = nn.CrossEntropyLoss()

# %%
# Converting numpy arrays into pytorch tensors
X_train = torch.Tensor(X_train)

# You must convert it into LongTensor. I did it once
y_train = torch.Tensor(y_train).type(torch.LongTensor)

X_test = torch.Tensor(X_test)
y_test = torch.Tensor(y_test)

EPOCHS = 30

for epoch in range(EPOCHS):

    # Clearing gradients
    optimizer.zero_grad()

    # Forward Propagation
    outs = ann_model(X_train)

    # Computing Loss
    loss = error(outs,y_train)

    # Backward propagation
    loss.backward()

    # Updating parameters
    optimizer.step()

    # Printing loss
    print(f"Loss after iteration {epoch} is {loss}")
# Out:
# Loss after iteration 0 is 0.25674736499786377
# Loss after iteration 1 is 0.2522221505641937
# Loss after iteration 2 is 0.21897408366203308
# Loss after iteration 3 is 0.20500536262989044
# Loss after iteration 4 is 0.1943807750940323
# Loss after iteration 5 is 0.18747924268245697
# Loss after iteration 6 is 0.180491104722023
# Loss after iteration 7 is 0.17457354068756104
# Loss after iteration 8 is 0.16434717178344727
# Loss after iteration 9 is 0.16005584597587585
# Loss after iteration 10 is 0.15886060893535614
# Loss after iteration 11 is 0.1473132073879242
# Loss after iteration 12 is 0.14291705191135406
# Loss after iteration 13 is 0.13722611963748932
# Loss after iteration 14 is 0.1349918395280838
# Loss after iteration 15 is 0.12849879264831543
# Loss after iteration 16 is 0.12617042660713196
# Loss after iteration 17 is 0.12013670057058334
# Loss after iteration 18 is 0.11721692234277725
# Loss after iteration 19 is 0.1139340028166771
# Loss after iteration 20 is 0.11293386667966843
# Loss after iteration 21 is 0.10689439624547958
# Loss after iteration 22 is 0.10748784244060516
# Loss after iteration 23 is 0.10240494459867477
# Loss after iteration 24 is 0.09845144301652908
# Loss after iteration 25 is 0.09634584933519363
# Loss after iteration 26 is 0.09249956905841827
# Loss after iteration 27 is 0.09254096448421478
# Loss after iteration 28 is 0.0911058560013771
# Loss after iteration 29 is 0.08956358581781387

# %%
# Importing metrics
from sklearn.metrics import accuracy_score,confusion_matrix


# Prediction
y_head = ann_model(X_test)
print(y_head[0])
# Converting Prediction into labels
y_pred = torch.max(y_head,1)[1]
print(y_pred[0])

# Accuracy score
print("Model accuracy is ",accuracy_score(y_pred,y_test))
# Out:
# tensor([ 12.4346, -11.1310], grad_fn=<SelectBackward0>)
# tensor(0)
# Model accuracy is  0.9696182516376779

# %%
confusion_matrix = confusion_matrix(y_pred=y_pred,y_true=y_test)

fig,ax = plt.subplots(figsize=(6,6))
sns.heatmap(confusion_matrix,annot=True,fmt="0.1f",linewidths=1.5)
plt.show()
