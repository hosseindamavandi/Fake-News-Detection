# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install -q ipython-autotime
# %load_ext autotime
# %load_ext autoreload
# %timeit
# %autoreload 2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.8 MB/s eta 0:00:00
# time: 12.9 ms (started: 2023-07-26 14:59:47 +00:00)

# %%
# %cd drive
# Out:
# /content/drive
# time: 13.9 ms (started: 2023-07-26 14:59:47 +00:00)

# %%
# %cd MyDrive
# Out:
# /content/drive/MyDrive
# time: 12.4 ms (started: 2023-07-26 14:59:47 +00:00)

# %%
# !ls
# Out:
# 'Colab Notebooks'		  FND		   kaggle.json	    Neuromatch
#  fake-and-real-news-dataset.zip   Invoice.gsheet   MPRNet-Article
# time: 119 ms (started: 2023-07-26 14:59:47 +00:00)

# %%
# %cd FND/new/Fake-News-Detection
# Out:
# /content/drive/MyDrive/FND/new/Fake-News-Detection
# time: 245 ms (started: 2023-07-26 14:59:47 +00:00)

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.0.1-py3-none-any.whl (729 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.22.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.1+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.1)
# Collecting lightning-utilities>=0.7.0 (from torchmetrics)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.7.0->torchmetrics) (4.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.9.0 torchmetrics-1.0.1
# time: 5.84 s (started: 2023-07-26 14:59:47 +00:00)

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from Utils import *
from preprocess import *
from models import ANN, CNN1D, BILSTM
from torch.utils.data import Dataset, DataLoader
# Out:
# time: 9.38 s (started: 2023-07-26 14:59:53 +00:00)

# %%
loaded_data = np.load("cleaned-dataset/data_npy.npy")
X_train, X_test, y_train, y_test = split_data(loaded_data, ratio=0.70, seed=42)

training_dataset = TextDataset(X_train, y_train)
testing_dataset = TextDataset(X_test, y_test)
train_loader = DataLoader(dataset=training_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(dataset=training_dataset, batch_size=128, shuffle=True)
# Out:
# time: 105 ms (started: 2023-07-26 15:00:48 +00:00)

# %%
# def acc_func(y_true, y_pred):
#     y_pred = torch.round(y_pred)
#     return (y_true == y_pred).sum() / len(y_true)
# Out:
# time: 70.5 ms (started: 2023-07-26 15:00:03 +00:00)

# %%
x, y = next(iter(train_loader))
x.shape, x.unsqueeze(1).shape, x.unsqueeze(-1).shape, x.unsqueeze(0).shape
# Out:
# (torch.Size([128, 100]),
#  torch.Size([128, 1, 100]),
#  torch.Size([128, 100, 1]),
#  torch.Size([1, 128, 100]))
# time: 142 ms (started: 2023-07-26 15:00:03 +00:00)

# %%
#* GLOABL VARIABLES
EPOCHS = 150
LEARNING_RATE = 3e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# DEVICE = torch.device("cpu")
# Out:
# time: 162 ms (started: 2023-07-26 15:00:04 +00:00)

# %%
# ANN
model = ANN().to(DEVICE)
# model = CNN1D().to(DEVICE)
# Out:
# time: 5.92 s (started: 2023-07-26 15:00:04 +00:00)

# %%
# # LSTM
# INPUT_SIZE = train_loader.dataset[0][0].shape[0]
# HIDDEN_STATE = 64
# NUM_LAYERS = 4
# NUM_CLASSES = 1 #* binary classification

# model = BILSTM(INPUT_SIZE, HIDDEN_STATE, NUM_LAYERS, NUM_CLASSES, bidirection=True).to(DEVICE)
# Out:
# time: 43.7 ms (started: 2023-07-26 13:44:01 +00:00)

# %%
loss = torch.nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# time: 42.1 ms (started: 2023-07-26 15:00:11 +00:00)

# %%
# torch.save(ann.state_dict(), "model.pth")
# ann_loaded = ANN().to(DEVICE)
# ann_loaded.load_state_dict(torch.load("model.pth"))
# Out:
# time: 34.3 ms (started: 2023-07-26 15:00:11 +00:00)

# %%
history = Training(
    model,
    train_loader,
    test_loader,
    EPOCHS,
    DEVICE,
    loss,
    optimizer,
    print_every=10,
    load_saved_model=True,
)
# Out:
# Loaded saved model model_files/ANN_best_model.pth successfully
# Epoch 0 | Train Loss: 0.19679
# Epoch 0 | Train Acc: 92.45%
# Epoch 0 | Test Loss: 0.16206
# Epoch 0 | Test Acc: 93.45%
# Test loss decreased to 0.16206 saving new best model
# --------------------------------------------------
# Epoch 10 | Train Loss: 0.10830
# Epoch 10 | Train Acc: 95.58%
# Epoch 10 | Test Loss: 0.07574
# Epoch 10 | Test Acc: 97.09%
# Test loss decreased from 0.08777 to 0.07574 saving new best model
# --------------------------------------------------
# Epoch 20 | Train Loss: 0.05837
# Epoch 20 | Train Acc: 97.66%
# Epoch 20 | Test Loss: 0.02922
# Epoch 20 | Test Acc: 99.14%
# Test loss decreased from 0.03062 to 0.02922 saving new best model
# --------------------------------------------------
# Epoch 30 | Train Loss: 0.03518
# Epoch 30 | Train Acc: 98.63%
# Epoch 30 | Test Loss: 0.01156
# Epoch 30 | Test Acc: 99.81%
# --------------------------------------------------
# Epoch 40 | Train Loss: 0.02226
# Epoch 40 | Train Acc: 99.24%
# Epoch 40 | Test Loss: 0.00445
# Epoch 40 | Test Acc: 99.97%
# Test loss decreased from 0.00590 to 0.00445 saving new best model
# --------------------------------------------------
# Epoch 50 | Train Loss: 0.02089
# Epoch 50 | Train Acc: 99.26%
# Epoch 50 | Test Loss: 0.00313
# Epoch 50 | Test Acc: 99.95%
# --------------------------------------------------
# Epoch 60 | Train Loss: 0.01276
# Epoch 60 | Train Acc: 99.56%
# Epoch 60 | Test Loss: 0.00182
# Epoch 60 | Test Acc: 99.96%
# --------------------------------------------------
# Epoch 70 | Train Loss: 0.01294
# Epoch 70 | Train Acc: 99.59%
# Epoch 70 | Test Loss: 0.00119
# Epoch 70 | Test Acc: 99.99%
# --------------------------------------------------
# Epoch 80 | Train Loss: 0.00815
# Epoch 80 | Train Acc: 99.71%
# Epoch 80 | Test Loss: 0.00063
# Epoch 80 | Test Acc: 99.99%
# --------------------------------------------------
# Epoch 90 | Train Loss: 0.00844
# Epoch 90 | Train Acc: 99.70%
# Epoch 90 | Test Loss: 0.00083
# Epoch 90 | Test Acc: 99.99%
# --------------------------------------------------
# Epoch 100 | Train Loss: 0.01011
# Epoch 100 | Train Acc: 99.67%
# Epoch 100 | Test Loss: 0.00042
# Epoch 100 | Test Acc: 100.00%
# --------------------------------------------------
# Epoch 110 | Train Loss: 0.00758
# Epoch 110 | Train Acc: 99.75%
# Epoch 110 | Test Loss: 0.00040
# Epoch 110 | Test Acc: 100.00%
# --------------------------------------------------
# Epoch 120 | Train Loss: 0.00763
# Epoch 120 | Train Acc: 99.77%
# Epoch 120 | Test Loss: 0.00053
# Epoch 120 | Test Acc: 100.00%
# --------------------------------------------------
# Epoch 130 | Train Loss: 0.00701
# Epoch 130 | Train Acc: 99.77%
# Epoch 130 | Test Loss: 0.00025
# Epoch 130 | Test Acc: 100.00%
# --------------------------------------------------
# Epoch 140 | Train Loss: 0.00407
# Epoch 140 | Train Acc: 99.86%
# Epoch 140 | Test Loss: 0.00010
# Epoch 140 | Test Acc: 100.00%
# Test loss decreased from 0.00012 to 0.00010 saving new best model
# --------------------------------------------------
# time: 2min 59s (started: 2023-07-26 15:00:51 +00:00)

# %%
# loaded_ann = ANN().to(DEVICE)
# loaded_ann.load_state_dict(torch.load("ANN_best_model.pth"))

# %%
path = "C:\\Users\\DELL\\OneDrive\\Desktop\\AI projects\\Fake-News-Detection\\word2vec_model\\word2vec.model"
word2vec_model = Load_word2vec(path)
# Out:
# Word2Vec model loaded successfully!
# time: 1.59 s (started: 2023-07-25 11:51:56 +03:00)

# %%
from preprocess import *
sample = "The billionaire changed his profile picture to the new logo and added X.com to his Twitter bio."

predict(sample, word2vec_model, model, DEVICE, prepare_for=model._get_name())
# sample = preprocess_text(sample)
# sample = vectorize_text(sample, word2vec_model)
# sample = torch.tensor(sample).float().to(DEVICE).unsqueeze(0).unsqueeze(1)
# print(sample.shape)
# model.eval()
# model(sample)
# print(predict(sample, word2vec_model, loaded_ann, DEVICE))
# Out:
# 'Real, with probability: 73.26%'
# time: 250 ms (started: 2023-07-25 11:52:33 +03:00)
